# %%
import cv2
from yolo_prediction import YOLO_Pred

# %%
yolo = YOLO_Pred('./Model2-20260322T135653Z-1-001/Model2/weights/best.onnx','data.yaml')

# %%
img = cv2.imread(r"C:\Users\Administrator\Documents\vs_code\yolo-object-detection\2_predictions\pexels-pashal-106052.jpg")

cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Prediction
img_pred = yolo.predictions(img)

# %%
cv2.imshow('img_prediction',img_pred)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
## Real Time Object Detection

# %%
cap = cv2.VideoCapture("vid.mp4")

# Get webcam size
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = 20.0

# Codec
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# Create output video writer
out = cv2.VideoWriter('output2.mp4', fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if ret == False:
        print('unable to read video')
        break

    pred_image = yolo.predictions(frame)

    # Save the processed frame
    out.write(pred_image)

    cv2.imshow('YOLO', pred_image)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
cap.release()
out.release()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Administrator\Documents\vs_code\yolo-object-detection\2_predictions
