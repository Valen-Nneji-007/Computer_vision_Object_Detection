# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/')

# %%
ls
# Out:
#  01_pytorch_workflow_video_2025.ipynb
# '02_neural_network_classification with_pytorch.ipynb'
# '03_PyTorch _computer_vision_video_2026.ipynb'
#  04_pyTorch_customs_Datasets_video.ipynb
# 'Building an Object Detection Model.ipynb'
# 'Cats Vs Dog.ipynb'
# 'Computer Vision book.ipynb'
# 'Copy of Basic Start.ipynb'
# 'Copy of Classification of dogs vs Cats Vgg16.ipynb'
# 'Copy of Computer Vision book.ipynb'
# 'Copy of Dogssscatsss.ipynb'
# 'Custom_Object_Detection_using_Detectron2(Faster_RCNN).ipynb'
#  Custom_object_Detection_using_Detectron2.ipynb
# 'Data Augmentation.ipynb'
# 'Deconstructing CNN Vision.ipynb'
#  Dogssscatsss.ipynb
# 'Filter demo.ipynb'
#  Image_classification_chest_disease.ipynb
#  Linear_model.ipynb
#  Main.ipynb
#  My_Aircraft_model.ipynb
#  My_training_model.ipynb
# 'numpy rehearsal.ipynb'
# 'OpenCv Intro.ipynb'
# 'Pretained models in CNN using tensorflow.ipynb'
#  Pytorch_fundamental_2025
#  Sign_language_Detection_using_YOLO_v5.ipynb
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17851, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 17851 (delta 34), reused 12 (delta 10), pack-reused 17801 (from 3)
# Receiving objects: 100% (17851/17851), 16.98 MiB | 12.33 MiB/s, done.
# Resolving deltas: 100% (12165/12165), done.
# Updating files: 100% (146/146), done.

# %%
os.chdir('yolov5')

# %%
ls
# Out:
# benchmarks.py    data/       LICENSE         README.zh-CN.md   tutorial.ipynb
# CITATION.cff     detect.py   models/         requirements.txt  utils/
# classify/        export.py   pyproject.toml  segment/          val.py
# CONTRIBUTING.md  hubconf.py  README.md       train.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 14.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
# !mv "/content/drive/MyDrive/data_images" "/content/drive/MyDrive/Colab Notebooks/yolov5/"

# %%
mv "/content/drive/MyDrive/data.yaml" "/content/drive/MyDrive/Colab Notebooks/yolov5/"

# %%
# !python train.py \
--data data.yaml \
 --cfg yolov5s.yaml \
  --batch-size 8 --name Model --epochs 50
# Out:
# Streaming output truncated to the last 5000 lines.
#       45/49         3G    0.02935    0.03063   0.004844         41        640:   1% 7/496 [00:01<02:29,  3.26it/s]/content/drive/MyDrive/Colab Notebooks/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       45/49         3G    0.03067    0.03097   0.005632         54        640:   2% 8/496 [00:02<03:03,  2.66it/s]/content/drive/MyDrive/Colab Notebooks/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/Model2/weights/best.pt yolov5s.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/Model2/weights/best.pt', 'yolov5s.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-463-g88af13e3 Python-3.12.12 torch-2.10.0+cu128 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/Model2/weights/best.pt with output shape (1, 25200, 25) (13.8 MB)
#
# TorchScript: starting export with torch 2.10.0+cu128...
# ...
